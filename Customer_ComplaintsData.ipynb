# %%
import pandas as pd

# %%
df = pd.read_csv('Consumer_Complaints.csv')
# Out:
# /Users/soudaminimodak/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0    07/29/2013            Consumer Loan                 Vehicle loan
# 1    07/29/2013  Bank account or service             Checking account
# 2    07/29/2013  Bank account or service             Checking account
# 3    07/29/2013  Bank account or service             Checking account
# 4    07/29/2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# ...

# %%
df.tail()
# Out:
#        Date received       Product               Sub-product  \
# 757878    08/07/2015  Student loan  Non-federal student loan
# 757879    04/17/2012  Student loan  Non-federal student loan
# 757880    08/18/2014  Student loan  Non-federal student loan
# 757881    02/11/2016  Student loan  Non-federal student loan
# 757882    09/05/2013  Student loan  Non-federal student loan
#
#                                       Issue  \
# 757878   Dealing with my lender or servicer
# 757879  Problems when you are unable to pay
# 757880   Dealing with my lender or servicer
# 757881                  Can't repay my loan
# 757882                   Repaying your loan
#
#                                      Sub-issue  \
# 757878        Keep getting calls about my loan
# 757879     Problems when you are unable to pay
# 757880  Received bad information about my loan
# 757881      Can't get flexible payment options
# 757882                      Repaying your loan
#
# ...

# %%
df1 = pd.read_csv('consumer_complaints_2.csv')
# Out:
# /Users/soudaminimodak/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head()
# Out:
#   date_received           product               sub_product  \
# 0    08/30/2013          Mortgage            Other mortgage
# 1    08/30/2013          Mortgage            Other mortgage
# 2    08/30/2013  Credit reporting                       NaN
# 3    08/30/2013      Student loan  Non-federal student loan
# 4    08/30/2013   Debt collection               Credit card
#
#                                       issue  \
# 0  Loan modification,collection,foreclosure
# 1  Loan servicing, payments, escrow account
# 2    Incorrect information on credit report
# 3                        Repaying your loan
# 4        False statements or representation
#
#                            sub_issue consumer_complaint_narrative  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                     Account status                          NaN
# ...

# %%
df1 = df1.rename(columns={'date_received':'Date received', 'product':'Product','sub_product':'Sub-product', 'issue': 'Issue',
                         'sub_issue': 'Sub-issue', 'consumer_complaint_narrative' :'Consumer complaint narrative',
                         'company_public_response':'Company public response', 'company' :'Company', 'state':'State',
                         'zipcode': 'ZIP code','tags': 'Tags','consumer_consent_provided':'Consumer consent provided?',
                         'submitted_via':'Submitted via', 'date_sent_to_company':'Date sent to company',
                         'company_response_to_consumer':'Company response to consumer','timely_response':'Timely response?',
                         'consumer_disputed?':'Consumer disputed?','complaint_id':'Complaint ID'})

# %%
#Two Files taken from websites: Data.gov and Kaggle. some of the feilds are seen null like sub-issue, narrative. No use considering those columns for analysis.

# %%
#Combining the two files for analysis

# %%
df1.head()
# Out:
#   Date received           Product               Sub-product  \
# 0    08/30/2013          Mortgage            Other mortgage
# 1    08/30/2013          Mortgage            Other mortgage
# 2    08/30/2013  Credit reporting                       NaN
# 3    08/30/2013      Student loan  Non-federal student loan
# 4    08/30/2013   Debt collection               Credit card
#
#                                       Issue  \
# 0  Loan modification,collection,foreclosure
# 1  Loan servicing, payments, escrow account
# 2    Incorrect information on credit report
# 3                        Repaying your loan
# 4        False statements or representation
#
#                            Sub-issue Consumer complaint narrative  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                     Account status                          NaN
# ...

# %%
len(df)
# Out:
# 757883

# %%
len(df1)
# Out:
# 555957

# %%
file = pd.concat([df,df1])

# %%
#Combined File

# %%
len(file)
# Out:
# 1313840

# %%
file.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0    07/29/2013            Consumer Loan                 Vehicle loan
# 1    07/29/2013  Bank account or service             Checking account
# 2    07/29/2013  Bank account or service             Checking account
# 3    07/29/2013  Bank account or service             Checking account
# 4    07/29/2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# ...

# %%
file = file.dropna(how='any')

# %%
file = file[['Date received', 'Product', 'Sub-product', 'Company','State', 'Submitted via','Timely response?','Consumer disputed?']]

# %%
# Clean data with required attributes for tableau

# %%
file
# Out:
#        Date received          Product                            Sub-product  \
# 56993     03/24/2015      Payday loan                            Payday loan
# 57150     03/19/2015  Debt collection                                Medical
# 57207     03/24/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 57286     03/19/2015  Debt collection                          I do not know
# 57299     03/19/2015  Debt collection                          I do not know
# 57319     03/19/2015  Debt collection                          I do not know
# 57420     03/24/2015  Debt collection                                Medical
# 57898     03/25/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 57992     04/03/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 58003     04/03/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 58423     04/09/2015  Debt collection                          I do not know
# ...

# %%
#Moving the combined file to csv for use in tableau

# %%
file.to_csv('ConsumerComplaints.csv', sep=';')
